# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaRyabkova/KR-Analitika/blob/main/%D0%9F%D1%80%D0%BE%D0%BC%D0%B5%D0%B6%D1%83%D1%82%D0%BE%D1%87%D0%BD%D0%B0%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("lm.csv", encoding="latin-1")
df
# Out:
#                          Client ID                   Domain       City  \
# 0      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru     Zurich
# 1      GA1.2.1029165320.1581675414  cars.BMW-keyauto-krd.ru     Zurich
# 2      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru     Zurich
# 3       GA1.2.360702973.1573932024       BMW-keyauto-krd.ru     Zurich
# 4      GA1.2.1394084210.1579796276    Mersedes-krasnodar.ru     Zurich
# ...                            ...                      ...        ...
# 31728   GA1.2.808166322.1581159620       BMW-keyauto-krd.ru  Krasnodar
# 31729   GA1.2.828311324.1577958698       BMW-keyauto-krd.ru  Krasnodar
# 31730   GA1.2.868499888.1581358110       BMW-keyauto-krd.ru  Krasnodar
# 31731   GA1.2.888008740.1579696173       BMW-keyauto-krd.ru  Krasnodar
# 31732   GA1.2.894200113.1580846871       BMW-keyauto-krd.ru  Krasnodar
#
#                Region    Browser Device Category                        Date  \
# ...

# %% [markdown]
# ## Анализ сессий по устройствам

# %%
m1 = df['Device Category'].value_counts()
m1.head()
# Out:
# mobile     18987
# desktop    11694
# tablet      1052
# Name: Device Category, dtype: int64

# %%
plt.figure(figsize=(10, 8))

plt.pie(m1.values, autopct='%1.1f%%')

plt.title('Количество сессий по устройствам')
plt.legend(m1.index);

# %%
df = pd.read_csv("data.csv", encoding="latin-1")
df.head()
# Out:
#          data  sum prodazi
# 0  01.01.2020          103
# 1  02.01.2020          146
# 2  03.01.2020          219
# 3  04.01.2020          210
# 4  05.01.2020          213

# %% [markdown]
# #### Посчитаем выручку за день = сумму продаж*среднюю стоимость авто (среднюю стоимость рассчитали в power bi - мера на вкладке аналитика = 4.98 млн)

# %%
df['viruchka'] = df['sum prodazi']*4.98
df.head ()
# Out:
#          data  sum prodazi  viruchka
# 0  01.01.2020          103    512.94
# 1  02.01.2020          146    727.08
# 2  03.01.2020          219   1090.62
# 3  04.01.2020          210   1045.80
# 4  05.01.2020          213   1060.74

# %% [markdown]
# Удалим столбец с суммой продаж

# %%
df.drop(columns=['sum prodazi'], inplace=True)
df.head()
# Out:
#          data  viruchka
# 0  01.01.2020    512.94
# 1  02.01.2020    727.08
# 2  03.01.2020   1090.62
# 3  04.01.2020   1045.80
# 4  05.01.2020   1060.74

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import math
import datetime

# %%
df['data'] = pd.to_datetime(df['data'], format='%d.%m.%Y')
df.head()
# Out:
#         data  viruchka
# 0 2020-01-01    512.94
# 1 2020-01-02    727.08
# 2 2020-01-03   1090.62
# 3 2020-01-04   1045.80
# 4 2020-01-05   1060.74

# %%
df=df.set_index('data')
df.head()
# Out:
#             viruchka
# data
# 2020-01-01    512.94
# 2020-01-02    727.08
# 2020-01-03   1090.62
# 2020-01-04   1045.80
# 2020-01-05   1060.74

# %%
df.plot()
plt.show()
